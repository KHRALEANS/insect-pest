# %%
import json


train_ann_file = 'mmdetection/data/pest-coco/annotations_v2/train_labels.json'
data_root_dir = '/root/autodl-tmp/datasets/pest-coco/AUG'
f = open(train_ann_file)
train_ann_dic = json.load(f)
train_ann_dic['categories']
# Out:
# [{'id': 1, 'name': '无', 'supercategory': 'insect'},
#  {'id': 2, 'name': '二化螟', 'supercategory': 'pest'},
#  {'id': 3, 'name': '二点委夜蛾', 'supercategory': 'pest'},
#  {'id': 4, 'name': '棉铃虫', 'supercategory': 'pest'},
#  {'id': 5, 'name': '褐飞虱属', 'supercategory': 'pest'},
#  {'id': 6, 'name': '白背飞虱', 'supercategory': 'pest'},
#  {'id': 7, 'name': '八点灰灯蛾', 'supercategory': 'pest'},
#  {'id': 8, 'name': '蝼蛄', 'supercategory': 'pest'},
#  {'id': 9, 'name': '蟋蟀', 'supercategory': 'pest'},
#  {'id': 10, 'name': '甜菜夜蛾', 'supercategory': 'pest'},
#  {'id': 11, 'name': '黄足猎蝽', 'supercategory': 'pest'},
#  {'id': 12, 'name': '稻纵卷叶螟', 'supercategory': 'pest'},
#  {'id': 13, 'name': '甜菜白带野螟', 'supercategory': 'pest'},
#  {'id': 14, 'name': '黄毒蛾', 'supercategory': 'pest'},
#  {'id': 15, 'name': '石蛾', 'supercategory': 'pest'},
#  {'id': 16, 'name': '大黑鳃金龟', 'supercategory': 'pest'},
#  {'id': 17, 'name': '粘虫', 'supercategory': 'pest'},
#  {'id': 18, 'name': '稻螟蛉', 'supercategory': 'pest'},
#  {'id': 19, 'name': '甘蓝夜蛾', 'supercategory': 'pest'},
#  {'id': 20, 'name': '地老虎', 'supercategory': 'pest'},
#  {'id': 21, 'name': '大螟', 'supercategory': 'pest'},
#  {'id': 22, 'name': '瓜绢野螟', 'supercategory': 'pest'},
#  {'id': 23, 'name': '线委夜蛾', 'supercategory': 'pest'},
#  {'id': 24, 'name': '水螟蛾', 'supercategory': 'pest'},
#  {'id': 25, 'name': '紫条尺蛾', 'supercategory': 'pest'},
#  {'id': 26, 'name': '歧角螟', 'supercategory': 'pest'},
#  {'id': 27, 'name': '草地螟', 'supercategory': 'pest'},
#  {'id': 28, 'name': '豆野螟', 'supercategory': 'pest'},
#  {'id': 29, 'name': '干纹冬夜蛾', 'supercategory': 'pest'}]
# [{'id': 1, 'name': '无', 'supercategory': 'insect'},
#  {'id': 2, 'name': '二化螟', 'supercategory': 'pest'},
#  {'id': 3, 'name': '二点委夜蛾', 'supercategory': 'pest'},
#  {'id': 4, 'name': '棉铃虫', 'supercategory': 'pest'},
#  {'id': 5, 'name': '褐飞虱属', 'supercategory': 'pest'},
#  {'id': 6, 'name': '白背飞虱', 'supercategory': 'pest'},
#  {'id': 7, 'name': '八点灰灯蛾', 'supercategory': 'pest'},
#  {'id': 8, 'name': '蝼蛄', 'supercategory': 'pest'},
#  {'id': 9, 'name': '蟋蟀', 'supercategory': 'pest'},
#  {'id': 10, 'name': '甜菜夜蛾', 'supercategory': 'pest'},
#  {'id': 11, 'name': '黄足猎蝽', 'supercategory': 'pest'},
#  {'id': 12, 'name': '稻纵卷叶螟', 'supercategory': 'pest'},
#  {'id': 13, 'name': '甜菜白带野螟', 'supercategory': 'pest'},
#  {'id': 14, 'name': '黄毒蛾', 'supercategory': 'pest'},
#  {'id': 15, 'name': '石蛾', 'supercategory': 'pest'},
#  {'id': 16, 'name': '大黑鳃金龟', 'supercategory': 'pest'},
#  {'id': 17, 'name': '粘虫', 'supercategory': 'pest'},
#  {'id': 18, 'name': '稻螟蛉', 'supercategory': 'pest'},
#  {'id': 19, 'name': '甘蓝夜蛾', 'supercategory': 'pest'},
#  {'id': 20, 'name': '地老虎', 'supercategory': 'pest'},
#  {'id': 21, 'name': '大螟', 'supercategory': 'pest'},
#  {'id': 22, 'name': '瓜绢野螟', 'supercategory': 'pest'},
#  {'id': 23, 'name': '线委夜蛾', 'supercategory': 'pest'},
#  {'id': 24, 'name': '水螟蛾', 'supercategory': 'pest'},
#  {'id': 25, 'name': '紫条尺蛾', 'supercategory': 'pest'},
#  {'id': 26, 'name': '歧角螟', 'supercategory': 'pest'},
#  {'id': 27, 'name': '草地螟', 'supercategory': 'pest'},
#  {'id': 28, 'name': '豆野螟', 'supercategory': 'pest'},
#  {'id': 29, 'name': '干纹冬夜蛾', 'supercategory': 'pest'}]

# %%
import os


for insect_category in train_ann_dic['categories']:
    pest_dir = os.path.join(data_root_dir,str(insect_category['id']))
    isExist = os.path.exists(pest_dir)
    if not isExist:
        os.mkdir(pest_dir)
        print(f'path {pest_dir} created!')
    else:
        print(f'path {pest_dir} exists')
# Out:
# path /root/autodl-tmp/datasets/pest-coco/AUG/1 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/2 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/3 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/4 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/5 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/6 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/7 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/8 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/9 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/10 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/11 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/12 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/13 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/14 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/15 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/16 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/17 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/18 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/19 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/20 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/21 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/22 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/23 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/24 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/25 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/26 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/27 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/28 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/29 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/1 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/2 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/3 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/4 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/5 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/6 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/7 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/8 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/9 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/10 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/11 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/12 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/13 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/14 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/15 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/16 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/17 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/18 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/19 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/20 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/21 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/22 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/23 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/24 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/25 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/26 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/27 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/28 exists
# path /root/autodl-tmp/datasets/pest-coco/AUG/29 exists

# %%
from PIL import Image


im = Image.open('mmdetection/data/pest-coco/train_v2/00006.jpg')
print(im.format, im.size, im.mode)
# Out:
# JPEG (5472, 3648) RGB
# JPEG (5472, 3648) RGB

# %%
for key in train_ann_dic:
    print(key)
# Out:
# images
# annotations
# categories
# images
# annotations
# categories

# %%
train_ann_dic['annotations'][0]
# Out:
# {'id': 2,
#  'image_id': 1459,
#  'category_id': 2,
#  'bbox': [1835, 1920, 299, 460],
#  'area': 137540,
#  'iscrowd': 0}
# {'id': 2,
#  'image_id': 1459,
#  'category_id': 2,
#  'bbox': [1835, 1920, 299, 460],
#  'area': 137540,
#  'iscrowd': 0}

# %%
train_ann_dic['annotations'][0]['bbox']
# Out:
# [1835, 1920, 299, 460]
# [1835, 1920, 299, 460]

# %%
train_ann_dic['images'][1]
# Out:
# {'id': 1, 'file_name': '02830.jpg', 'height': 3648, 'width': 5472}
# {'id': 1, 'file_name': '02830.jpg', 'height': 3648, 'width': 5472}

# %%
images_index = [-1] * 100
for i, image_ele in enumerate(train_ann_dic['images']):
    while image_ele['id'] > len(images_index) - 1:
        images_index += [-1] * 100
    images_index[image_ele['id']] = i

# %%
img_dir = 'mmdetection/data/pest-coco/train_v2/'

img_name = train_ann_dic['images'][images_index[train_ann_dic['annotations'][0]['image_id']]]['file_name']

img_file = os.path.join(img_dir, img_name)

img_file
# Out:
# 'mmdetection/data/pest-coco/train_v2/00008.jpg'
# 'mmdetection/data/pest-coco/train_v2/00008.jpg'

# %%
import numpy as np
im = Image.open(img_file)

pix = np.array(im)

# %%
bbox = train_ann_dic['annotations'][0]['bbox']

x1, x2, y1, y2 = bbox[0], bbox[0]+bbox[2], bbox[1], bbox[1]+bbox[3]

# %%
pest_slice = pix[y1:y2,x1:x2,:]

# %%
pest_im = Image.fromarray(pest_slice)

# %%
'''# ranned onece
# crop train image
for i, annotation_ele in enumerate(train_ann_dic['annotations']):
    # get original train image
    img_name = train_ann_dic['images'][images_index[annotation_ele['image_id']]]['file_name']
    img_file = os.path.join(img_dir, img_name)

    # get image pixel
    im = Image.open(img_file)
    pix = np.array(im)

    # crop insect pixel
    bbox = annotation_ele['bbox']
    x1, x2, y1, y2 = bbox[0], bbox[0]+bbox[2], bbox[1], bbox[1]+bbox[3]
    pest_slice = pix[y1:y2,x1:x2,:]
    pest_im = Image.fromarray(pest_slice)

    # dir name denote category_id ，file name denote annotaion index
    cropped_img_name = str(i)+'.jpg'
    outfile = os.path.join(data_root_dir, str(annotation_ele['category_id']), cropped_img_name)
    pest_im.save(outfile)
'''
# Out:
# "# ranned onece\n# crop train image\nfor i, annotation_ele in enumerate(train_ann_dic['annotations']):\n    # get original train image\n    img_name = train_ann_dic['images'][images_index[annotation_ele['image_id']]]['file_name']\n    img_file = os.path.join(img_dir, img_name)\n\n    # get image pixel\n    im = Image.open(img_file)\n    pix = np.array(im)\n\n    # crop insect pixel\n    bbox = annotation_ele['bbox']\n    x1, x2, y1, y2 = bbox[0], bbox[0]+bbox[2], bbox[1], bbox[1]+bbox[3]\n    pest_slice = pix[y1:y2,x1:x2,:]\n    pest_im = Image.fromarray(pest_slice)\n\n    # dir name denote category_id ，file name denote annotaion index\n    cropped_img_name = str(i)+'.jpg'\n    outfile = os.path.join(data_root_dir, str(annotation_ele['category_id']), cropped_img_name)\n    pest_im.save(outfile)\n"
# "# ranned onece\n# crop train image\nfor i, annotation_ele in enumerate(train_ann_dic['annotations']):\n    # get original train image\n    img_name = train_ann_dic['images'][images_index[annotation_ele['image_id']]]['file_name']\n    img_file = os.path.join(img_dir, img_name)\n\n    # get image pixel\n    im = Image.open(img_file)\n    pix = np.array(im)\n\n    # crop insect pixel\n    bbox = annotation_ele['bbox']\n    x1, x2, y1, y2 = bbox[0], bbox[0]+bbox[2], bbox[1], bbox[1]+bbox[3]\n    pest_slice = pix[y1:y2,x1:x2,:]\n    pest_im = Image.fromarray(pest_slice)\n\n    # dir name denote category_id ，file name denote annotaion index\n    cropped_img_name = str(i)+'.jpg'\n    outfile = os.path.join(data_root_dir, str(annotation_ele['category_id']), cropped_img_name)\n    pest_im.save(outfile)\n"

# %%
train_ann_dic['categories'][4]
# Out:
# {'id': 5, 'name': '褐飞虱属', 'supercategory': 'pest'}
# {'id': 5, 'name': '褐飞虱属', 'supercategory': 'pest'}

# %%
# original val dataset annotations
val_ann_file = 'mmdetection/data/pest-coco/annotations_v2/val_labels.json'
f = open(val_ann_file)
val_ann_dic = json.load(f)

# original val image dir
val_img_dir = 'mmdetection/data/pest-coco/val_v2/'

val_images_index = [-1] * 100
for i, image_ele in enumerate(val_ann_dic['images']):
    while image_ele['id'] > len(val_images_index) - 1:
        val_images_index += [-1] * 100
    val_images_index[image_ele['id']] = i

# %%
'''# ran once
for i, annotation_ele in enumerate(val_ann_dic['annotations']):
    # get original train image
    img_name = val_ann_dic['images'][val_images_index[annotation_ele['image_id']]]['file_name']
    img_file = os.path.join(val_img_dir, img_name)

    # get image pixel
    im = Image.open(img_file)
    pix = np.array(im)

    # crop insect pixel
    bbox = annotation_ele['bbox']
    x1, x2, y1, y2 = bbox[0], bbox[0]+bbox[2], bbox[1], bbox[1]+bbox[3]
    pest_slice = pix[y1:y2,x1:x2,:]
    pest_im = Image.fromarray(pest_slice)

    # dir name denote category_id ，file name denote annotaion index
    cropped_img_name = str(i)+ '_val' +'.jpg'
    outfile = os.path.join(data_root_dir, str(annotation_ele['category_id']), cropped_img_name)
    pest_im.save(outfile)
'''
# Out:
# "# ran once\nfor i, annotation_ele in enumerate(val_ann_dic['annotations']):\n    # get original train image\n    img_name = val_ann_dic['images'][val_images_index[annotation_ele['image_id']]]['file_name']\n    img_file = os.path.join(val_img_dir, img_name)\n\n    # get image pixel\n    im = Image.open(img_file)\n    pix = np.array(im)\n\n    # crop insect pixel\n    bbox = annotation_ele['bbox']\n    x1, x2, y1, y2 = bbox[0], bbox[0]+bbox[2], bbox[1], bbox[1]+bbox[3]\n    pest_slice = pix[y1:y2,x1:x2,:]\n    pest_im = Image.fromarray(pest_slice)\n\n    # dir name denote category_id ，file name denote annotaion index\n    cropped_img_name = str(i)+ '_val' +'.jpg'\n    outfile = os.path.join(data_root_dir, str(annotation_ele['category_id']), cropped_img_name)\n    pest_im.save(outfile)\n"
# "# ran once\nfor i, annotation_ele in enumerate(val_ann_dic['annotations']):\n    # get original train image\n    img_name = val_ann_dic['images'][val_images_index[annotation_ele['image_id']]]['file_name']\n    img_file = os.path.join(val_img_dir, img_name)\n\n    # get image pixel\n    im = Image.open(img_file)\n    pix = np.array(im)\n\n    # crop insect pixel\n    bbox = annotation_ele['bbox']\n    x1, x2, y1, y2 = bbox[0], bbox[0]+bbox[2], bbox[1], bbox[1]+bbox[3]\n    pest_slice = pix[y1:y2,x1:x2,:]\n    pest_im = Image.fromarray(pest_slice)\n\n    # dir name denote category_id ，file name denote annotaion index\n    cropped_img_name = str(i)+ '_val' +'.jpg'\n    outfile = os.path.join(data_root_dir, str(annotation_ele['category_id']), cropped_img_name)\n    pest_im.save(outfile)\n"

# %%
val_ann_dic['images']
# Out:
# [{'id': 1770, 'file_name': '03050.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1771, 'file_name': '00062.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1772, 'file_name': '02565.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1773, 'file_name': '03525.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1774, 'file_name': '02557.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1775, 'file_name': '01665.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1776, 'file_name': '00457.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1777, 'file_name': '00728.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1778, 'file_name': '02370.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1779, 'file_name': '01158.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1780, 'file_name': '00619.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1781, 'file_name': '02296.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1782, 'file_name': '02169.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1783, 'file_name': '03670.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1784, 'file_name': '01981.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1785, 'file_name': '02975.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1786, 'file_name': '02787.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1787, 'file_name': '01932.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1788, 'file_name': '02687.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1789, 'file_name': '01656.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1790, 'file_name': '03475.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1791, 'file_name': '01968.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1792, 'file_name': '02338.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1793, 'file_name': '03231.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1794, 'file_name': '00037.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1795, 'file_name': '02466.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1796, 'file_name': '02881.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1797, 'file_name': '00492.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1798, 'file_name': '01233.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1799, 'file_name': '01934.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1800, 'file_name': '02686.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1801, 'file_name': '02004.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1802, 'file_name': '03472.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1803, 'file_name': '03221.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1804, 'file_name': '01256.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1805, 'file_name': '01926.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1806, 'file_name': '00957.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1807, 'file_name': '01939.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1808, 'file_name': '01598.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1809, 'file_name': '00163.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1810, 'file_name': '02380.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1811, 'file_name': '01376.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1812, 'file_name': '01216.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1813, 'file_name': '03760.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1814, 'file_name': '03158.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1815, 'file_name': '00404.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1816, 'file_name': '01509.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1817, 'file_name': '00270.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1818, 'file_name': '03086.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1819, 'file_name': '02907.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1820, 'file_name': '03287.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1821, 'file_name': '01046.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1822, 'file_name': '02056.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1823, 'file_name': '00340.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1824, 'file_name': '02440.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1825, 'file_name': '02486.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1826, 'file_name': '00531.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1827, 'file_name': '00544.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1828, 'file_name': '00632.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1829, 'file_name': '03016.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1830, 'file_name': '03740.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1831, 'file_name': '03747.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1832, 'file_name': '00150.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1833, 'file_name': '02361.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1834, 'file_name': '02613.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1835, 'file_name': '02861.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1836, 'file_name': '00049.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1837, 'file_name': '00576.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1838, 'file_name': '00392.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1839, 'file_name': '01069.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1840, 'file_name': '01366.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1841, 'file_name': '03542.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1842, 'file_name': '03766.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1843, 'file_name': '00825.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1844, 'file_name': '03736.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1845, 'file_name': '03249.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1846, 'file_name': '02367.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1847, 'file_name': '02366.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1848, 'file_name': '01217.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1849, 'file_name': '01862.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1850, 'file_name': '03311.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1851, 'file_name': '02123.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1852, 'file_name': '02652.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1853, 'file_name': '01231.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1854, 'file_name': '03422.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1855, 'file_name': '00179.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1856, 'file_name': '02067.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1857, 'file_name': '00689.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1858, 'file_name': '02109.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1859, 'file_name': '01581.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1860, 'file_name': '00655.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1861, 'file_name': '02467.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1862, 'file_name': '02191.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1863, 'file_name': '01828.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1864, 'file_name': '01548.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1865, 'file_name': '01672.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1866, 'file_name': '01796.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1867, 'file_name': '01745.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1868, 'file_name': '00599.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1869, 'file_name': '02132.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1870, 'file_name': '02201.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1871, 'file_name': '01395.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1872, 'file_name': '01430.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1873, 'file_name': '00242.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1874, 'file_name': '01488.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1875, 'file_name': '03595.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1876, 'file_name': '00323.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1877, 'file_name': '00817.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1878, 'file_name': '01602.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1879, 'file_name': '00790.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1880, 'file_name': '03487.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1881, 'file_name': '02947.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1882, 'file_name': '03694.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1883, 'file_name': '01540.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1884, 'file_name': '01607.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1885, 'file_name': '00669.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1886, 'file_name': '01776.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1887, 'file_name': '03464.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1888, 'file_name': '00116.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1889, 'file_name': '02713.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1890, 'file_name': '01413.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1891, 'file_name': '02333.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1892, 'file_name': '02096.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1893, 'file_name': '02836.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1894, 'file_name': '02326.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1895, 'file_name': '03603.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1896, 'file_name': '00265.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1897, 'file_name': '03012.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1898, 'file_name': '02111.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1899, 'file_name': '03163.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1900, 'file_name': '02214.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1901, 'file_name': '01830.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1902, 'file_name': '01807.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1903, 'file_name': '00370.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1904, 'file_name': '00529.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1905, 'file_name': '00112.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1906, 'file_name': '01344.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1907, 'file_name': '01987.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1908, 'file_name': '01770.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1909, 'file_name': '03517.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1910, 'file_name': '01998.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1911, 'file_name': '01868.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1912, 'file_name': '02190.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1913, 'file_name': '01085.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1914, 'file_name': '02321.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1915, 'file_name': '01741.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1916, 'file_name': '01841.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1917, 'file_name': '02608.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1918, 'file_name': '03813.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1919, 'file_name': '00515.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1920, 'file_name': '01463.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1921, 'file_name': '02220.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1922, 'file_name': '03279.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1923, 'file_name': '01664.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1924, 'file_name': '00722.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1925, 'file_name': '02927.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1926, 'file_name': '00228.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1927, 'file_name': '00205.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1928, 'file_name': '02964.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1929, 'file_name': '01014.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1930, 'file_name': '02405.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1931, 'file_name': '01129.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1932, 'file_name': '03110.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1933, 'file_name': '02130.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1934, 'file_name': '03356.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1935, 'file_name': '02489.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1936, 'file_name': '01293.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1937, 'file_name': '00755.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1938, 'file_name': '01869.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1939, 'file_name': '00363.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1940, 'file_name': '02420.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1941, 'file_name': '02854.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1942, 'file_name': '01092.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1943, 'file_name': '01170.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1944, 'file_name': '00125.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1945, 'file_name': '02744.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1946, 'file_name': '01018.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1947, 'file_name': '01209.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1948, 'file_name': '03263.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1949, 'file_name': '01113.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1950, 'file_name': '01278.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1951, 'file_name': '02967.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1952, 'file_name': '03778.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1953, 'file_name': '03182.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1954, 'file_name': '01063.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1955, 'file_name': '00532.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1956, 'file_name': '03566.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1957, 'file_name': '02961.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1958, 'file_name': '02719.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1959, 'file_name': '02346.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1960, 'file_name': '02555.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1961, 'file_name': '02648.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1962, 'file_name': '01610.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1963, 'file_name': '02492.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1964, 'file_name': '00748.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1965, 'file_name': '01185.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1966, 'file_name': '00177.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1967, 'file_name': '01263.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1968, 'file_name': '03419.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1969, 'file_name': '01578.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1970, 'file_name': '02149.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1971, 'file_name': '02343.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1972, 'file_name': '01306.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1973, 'file_name': '02813.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1974, 'file_name': '01304.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1975, 'file_name': '03678.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1976, 'file_name': '02739.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1977, 'file_name': '00357.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1978, 'file_name': '02008.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1979, 'file_name': '00119.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1980, 'file_name': '00417.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1981, 'file_name': '02674.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1982, 'file_name': '02178.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1983, 'file_name': '03601.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1984, 'file_name': '01746.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1985, 'file_name': '02543.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1986, 'file_name': '01439.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1987, 'file_name': '03568.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1988, 'file_name': '01922.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1989, 'file_name': '01867.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1990, 'file_name': '01611.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1991, 'file_name': '01102.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1992, 'file_name': '02610.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1993, 'file_name': '02694.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1994, 'file_name': '03250.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1995, 'file_name': '02374.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1996, 'file_name': '03178.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1997, 'file_name': '02364.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1998, 'file_name': '03019.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1999, 'file_name': '00207.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2000, 'file_name': '03712.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2001, 'file_name': '00650.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2002, 'file_name': '00193.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2003, 'file_name': '01537.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2004, 'file_name': '00858.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2005, 'file_name': '03617.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2006, 'file_name': '01022.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2007, 'file_name': '03710.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2008, 'file_name': '03763.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2009, 'file_name': '01015.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2010, 'file_name': '03114.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2011, 'file_name': '00991.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2012, 'file_name': '03650.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2013, 'file_name': '00001.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2014, 'file_name': '02915.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2015, 'file_name': '03438.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2016, 'file_name': '00800.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2017, 'file_name': '03136.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2018, 'file_name': '01396.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2019, 'file_name': '00913.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2020, 'file_name': '03162.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2021, 'file_name': '03743.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2022, 'file_name': '01501.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2023, 'file_name': '02958.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2024, 'file_name': '02617.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2025, 'file_name': '00934.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2026, 'file_name': '03390.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2027, 'file_name': '00634.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2028, 'file_name': '03723.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2029, 'file_name': '00773.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2030, 'file_name': '02353.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2031, 'file_name': '00336.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2032, 'file_name': '03639.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2033, 'file_name': '02484.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2034, 'file_name': '01633.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2035, 'file_name': '02579.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2036, 'file_name': '03549.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2037, 'file_name': '00397.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2038, 'file_name': '03347.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2039, 'file_name': '02710.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2040, 'file_name': '02595.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2041, 'file_name': '03394.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2042, 'file_name': '01362.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2043, 'file_name': '00466.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2044, 'file_name': '03461.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2045, 'file_name': '02308.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2046, 'file_name': '00036.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2047, 'file_name': '00074.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2048, 'file_name': '03335.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2049, 'file_name': '01370.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2050, 'file_name': '01573.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2051, 'file_name': '03423.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2052, 'file_name': '01443.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2053, 'file_name': '00449.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2054, 'file_name': '02614.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2055, 'file_name': '00111.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2056, 'file_name': '02982.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2057, 'file_name': '00399.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2058, 'file_name': '00772.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2059, 'file_name': '00366.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2060, 'file_name': '02090.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2061, 'file_name': '00989.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2062, 'file_name': '03793.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2063, 'file_name': '02340.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2064, 'file_name': '02657.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2065, 'file_name': '03316.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2066, 'file_name': '02233.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2067, 'file_name': '01958.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2068, 'file_name': '02066.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2069, 'file_name': '02047.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2070, 'file_name': '01496.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2071, 'file_name': '00594.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2072, 'file_name': '01429.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2073, 'file_name': '01464.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2074, 'file_name': '02387.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2075, 'file_name': '03371.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2076, 'file_name': '00102.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2077, 'file_name': '00215.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2078, 'file_name': '00439.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2079, 'file_name': '03530.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2080, 'file_name': '03038.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2081, 'file_name': '01716.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2082, 'file_name': '02385.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2083, 'file_name': '03520.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2084, 'file_name': '01539.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2085, 'file_name': '01377.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2086, 'file_name': '00338.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2087, 'file_name': '03246.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2088, 'file_name': '02573.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2089, 'file_name': '03405.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2090, 'file_name': '02320.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2091, 'file_name': '02171.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2092, 'file_name': '03634.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2093, 'file_name': '01065.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2094, 'file_name': '01511.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2095, 'file_name': '03059.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2096, 'file_name': '01196.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2097, 'file_name': '00421.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2098, 'file_name': '02871.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2099, 'file_name': '00188.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2100, 'file_name': '02847.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2101, 'file_name': '01959.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2102, 'file_name': '00129.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2103, 'file_name': '02222.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2104, 'file_name': '01093.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2105, 'file_name': '00025.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2106, 'file_name': '01391.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2107, 'file_name': '02054.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2108, 'file_name': '03227.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2109, 'file_name': '01487.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2110, 'file_name': '00963.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2111, 'file_name': '01312.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2112, 'file_name': '02007.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2113, 'file_name': '00472.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2114, 'file_name': '02033.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2115, 'file_name': '01326.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2116, 'file_name': '01832.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2117, 'file_name': '01805.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2118, 'file_name': '01681.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2119, 'file_name': '00636.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2120, 'file_name': '01995.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2121, 'file_name': '02677.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2122, 'file_name': '03265.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2123, 'file_name': '01061.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2124, 'file_name': '01029.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2125, 'file_name': '01552.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2126, 'file_name': '03518.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2127, 'file_name': '03811.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2128, 'file_name': '01519.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2129, 'file_name': '02747.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2130, 'file_name': '02896.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2131, 'file_name': '02837.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2132, 'file_name': '03516.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2133, 'file_name': '03280.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2134, 'file_name': '00732.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2135, 'file_name': '03538.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2136, 'file_name': '02212.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2137, 'file_name': '01844.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2138, 'file_name': '02330.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2139, 'file_name': '02611.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2140, 'file_name': '01457.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2141, 'file_name': '02553.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2142, 'file_name': '00939.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2143, 'file_name': '03075.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2144, 'file_name': '00459.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2145, 'file_name': '01176.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2146, 'file_name': '00712.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2147, 'file_name': '02841.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2148, 'file_name': '03720.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2149, 'file_name': '03286.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2150, 'file_name': '00527.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2151, 'file_name': '00930.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2152, 'file_name': '01380.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2153, 'file_name': '00749.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2154, 'file_name': '01139.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2155, 'file_name': '03083.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2156, 'file_name': '01892.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2157, 'file_name': '00905.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2158, 'file_name': '03166.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2159, 'file_name': '02839.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2160, 'file_name': '02937.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2161, 'file_name': '00727.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2162, 'file_name': '01307.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2163, 'file_name': '00765.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2164, 'file_name': '00666.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2165, 'file_name': '01977.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2166, 'file_name': '02987.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2167, 'file_name': '02271.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2168, 'file_name': '02983.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2169, 'file_name': '00195.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2170, 'file_name': '00208.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2171, 'file_name': '00949.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2172, 'file_name': '03064.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2173, 'file_name': '00030.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2174, 'file_name': '01789.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2175, 'file_name': '03098.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2176, 'file_name': '02272.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2177, 'file_name': '00236.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2178, 'file_name': '01936.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2179, 'file_name': '03201.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2180, 'file_name': '02758.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2181, 'file_name': '00761.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2182, 'file_name': '00823.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2183, 'file_name': '00516.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2184, 'file_name': '02978.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2185, 'file_name': '03399.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2186, 'file_name': '01614.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2187, 'file_name': '00390.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2188, 'file_name': '00114.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2189, 'file_name': '01195.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2190, 'file_name': '03127.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2191, 'file_name': '01858.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2192, 'file_name': '02960.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2193, 'file_name': '00498.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2194, 'file_name': '02878.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2195, 'file_name': '02016.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2196, 'file_name': '02586.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2197, 'file_name': '00299.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2198, 'file_name': '01851.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2199, 'file_name': '00280.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2200, 'file_name': '03672.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2201, 'file_name': '03224.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2202, 'file_name': '02163.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2203, 'file_name': '03060.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2204, 'file_name': '00106.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2205, 'file_name': '02203.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2206, 'file_name': '02932.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2207, 'file_name': '03661.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2208, 'file_name': '00458.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2209, 'file_name': '02176.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2210, 'file_name': '03132.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2211, 'file_name': '02022.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2212, 'file_name': '03757.jpg', 'height': 3648, 'width': 5472}]
# [{'id': 1770, 'file_name': '03050.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1771, 'file_name': '00062.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1772, 'file_name': '02565.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1773, 'file_name': '03525.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1774, 'file_name': '02557.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1775, 'file_name': '01665.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1776, 'file_name': '00457.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1777, 'file_name': '00728.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1778, 'file_name': '02370.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1779, 'file_name': '01158.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1780, 'file_name': '00619.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1781, 'file_name': '02296.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1782, 'file_name': '02169.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1783, 'file_name': '03670.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1784, 'file_name': '01981.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1785, 'file_name': '02975.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1786, 'file_name': '02787.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1787, 'file_name': '01932.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1788, 'file_name': '02687.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1789, 'file_name': '01656.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1790, 'file_name': '03475.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1791, 'file_name': '01968.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1792, 'file_name': '02338.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1793, 'file_name': '03231.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1794, 'file_name': '00037.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1795, 'file_name': '02466.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1796, 'file_name': '02881.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1797, 'file_name': '00492.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1798, 'file_name': '01233.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1799, 'file_name': '01934.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1800, 'file_name': '02686.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1801, 'file_name': '02004.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1802, 'file_name': '03472.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1803, 'file_name': '03221.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1804, 'file_name': '01256.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1805, 'file_name': '01926.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1806, 'file_name': '00957.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1807, 'file_name': '01939.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1808, 'file_name': '01598.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1809, 'file_name': '00163.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1810, 'file_name': '02380.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1811, 'file_name': '01376.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1812, 'file_name': '01216.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1813, 'file_name': '03760.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1814, 'file_name': '03158.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1815, 'file_name': '00404.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1816, 'file_name': '01509.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1817, 'file_name': '00270.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1818, 'file_name': '03086.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1819, 'file_name': '02907.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1820, 'file_name': '03287.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1821, 'file_name': '01046.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1822, 'file_name': '02056.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1823, 'file_name': '00340.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1824, 'file_name': '02440.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1825, 'file_name': '02486.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1826, 'file_name': '00531.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1827, 'file_name': '00544.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1828, 'file_name': '00632.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1829, 'file_name': '03016.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1830, 'file_name': '03740.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1831, 'file_name': '03747.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1832, 'file_name': '00150.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1833, 'file_name': '02361.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1834, 'file_name': '02613.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1835, 'file_name': '02861.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1836, 'file_name': '00049.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1837, 'file_name': '00576.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1838, 'file_name': '00392.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1839, 'file_name': '01069.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1840, 'file_name': '01366.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1841, 'file_name': '03542.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1842, 'file_name': '03766.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1843, 'file_name': '00825.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1844, 'file_name': '03736.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1845, 'file_name': '03249.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1846, 'file_name': '02367.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1847, 'file_name': '02366.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1848, 'file_name': '01217.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1849, 'file_name': '01862.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1850, 'file_name': '03311.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1851, 'file_name': '02123.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1852, 'file_name': '02652.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1853, 'file_name': '01231.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1854, 'file_name': '03422.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1855, 'file_name': '00179.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1856, 'file_name': '02067.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1857, 'file_name': '00689.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1858, 'file_name': '02109.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1859, 'file_name': '01581.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1860, 'file_name': '00655.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1861, 'file_name': '02467.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1862, 'file_name': '02191.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1863, 'file_name': '01828.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1864, 'file_name': '01548.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1865, 'file_name': '01672.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1866, 'file_name': '01796.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1867, 'file_name': '01745.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1868, 'file_name': '00599.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1869, 'file_name': '02132.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1870, 'file_name': '02201.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1871, 'file_name': '01395.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1872, 'file_name': '01430.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1873, 'file_name': '00242.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1874, 'file_name': '01488.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1875, 'file_name': '03595.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1876, 'file_name': '00323.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1877, 'file_name': '00817.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1878, 'file_name': '01602.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1879, 'file_name': '00790.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1880, 'file_name': '03487.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1881, 'file_name': '02947.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1882, 'file_name': '03694.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1883, 'file_name': '01540.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1884, 'file_name': '01607.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1885, 'file_name': '00669.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1886, 'file_name': '01776.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1887, 'file_name': '03464.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1888, 'file_name': '00116.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1889, 'file_name': '02713.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1890, 'file_name': '01413.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1891, 'file_name': '02333.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1892, 'file_name': '02096.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1893, 'file_name': '02836.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1894, 'file_name': '02326.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1895, 'file_name': '03603.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1896, 'file_name': '00265.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1897, 'file_name': '03012.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1898, 'file_name': '02111.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1899, 'file_name': '03163.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1900, 'file_name': '02214.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1901, 'file_name': '01830.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1902, 'file_name': '01807.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1903, 'file_name': '00370.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1904, 'file_name': '00529.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1905, 'file_name': '00112.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1906, 'file_name': '01344.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1907, 'file_name': '01987.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1908, 'file_name': '01770.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1909, 'file_name': '03517.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1910, 'file_name': '01998.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1911, 'file_name': '01868.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1912, 'file_name': '02190.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1913, 'file_name': '01085.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1914, 'file_name': '02321.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1915, 'file_name': '01741.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1916, 'file_name': '01841.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1917, 'file_name': '02608.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1918, 'file_name': '03813.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1919, 'file_name': '00515.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1920, 'file_name': '01463.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1921, 'file_name': '02220.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1922, 'file_name': '03279.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1923, 'file_name': '01664.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1924, 'file_name': '00722.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1925, 'file_name': '02927.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1926, 'file_name': '00228.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1927, 'file_name': '00205.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1928, 'file_name': '02964.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1929, 'file_name': '01014.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1930, 'file_name': '02405.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1931, 'file_name': '01129.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1932, 'file_name': '03110.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1933, 'file_name': '02130.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1934, 'file_name': '03356.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1935, 'file_name': '02489.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1936, 'file_name': '01293.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1937, 'file_name': '00755.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1938, 'file_name': '01869.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1939, 'file_name': '00363.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1940, 'file_name': '02420.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1941, 'file_name': '02854.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1942, 'file_name': '01092.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1943, 'file_name': '01170.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1944, 'file_name': '00125.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1945, 'file_name': '02744.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1946, 'file_name': '01018.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1947, 'file_name': '01209.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1948, 'file_name': '03263.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1949, 'file_name': '01113.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1950, 'file_name': '01278.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1951, 'file_name': '02967.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1952, 'file_name': '03778.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1953, 'file_name': '03182.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1954, 'file_name': '01063.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1955, 'file_name': '00532.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1956, 'file_name': '03566.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1957, 'file_name': '02961.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1958, 'file_name': '02719.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1959, 'file_name': '02346.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1960, 'file_name': '02555.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1961, 'file_name': '02648.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1962, 'file_name': '01610.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1963, 'file_name': '02492.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1964, 'file_name': '00748.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1965, 'file_name': '01185.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1966, 'file_name': '00177.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1967, 'file_name': '01263.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1968, 'file_name': '03419.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1969, 'file_name': '01578.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1970, 'file_name': '02149.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1971, 'file_name': '02343.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1972, 'file_name': '01306.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1973, 'file_name': '02813.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1974, 'file_name': '01304.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1975, 'file_name': '03678.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1976, 'file_name': '02739.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1977, 'file_name': '00357.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1978, 'file_name': '02008.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1979, 'file_name': '00119.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1980, 'file_name': '00417.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1981, 'file_name': '02674.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1982, 'file_name': '02178.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1983, 'file_name': '03601.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1984, 'file_name': '01746.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1985, 'file_name': '02543.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1986, 'file_name': '01439.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1987, 'file_name': '03568.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1988, 'file_name': '01922.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1989, 'file_name': '01867.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1990, 'file_name': '01611.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1991, 'file_name': '01102.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1992, 'file_name': '02610.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1993, 'file_name': '02694.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1994, 'file_name': '03250.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1995, 'file_name': '02374.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1996, 'file_name': '03178.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1997, 'file_name': '02364.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1998, 'file_name': '03019.jpg', 'height': 3648, 'width': 5472},
#  {'id': 1999, 'file_name': '00207.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2000, 'file_name': '03712.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2001, 'file_name': '00650.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2002, 'file_name': '00193.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2003, 'file_name': '01537.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2004, 'file_name': '00858.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2005, 'file_name': '03617.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2006, 'file_name': '01022.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2007, 'file_name': '03710.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2008, 'file_name': '03763.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2009, 'file_name': '01015.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2010, 'file_name': '03114.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2011, 'file_name': '00991.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2012, 'file_name': '03650.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2013, 'file_name': '00001.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2014, 'file_name': '02915.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2015, 'file_name': '03438.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2016, 'file_name': '00800.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2017, 'file_name': '03136.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2018, 'file_name': '01396.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2019, 'file_name': '00913.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2020, 'file_name': '03162.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2021, 'file_name': '03743.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2022, 'file_name': '01501.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2023, 'file_name': '02958.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2024, 'file_name': '02617.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2025, 'file_name': '00934.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2026, 'file_name': '03390.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2027, 'file_name': '00634.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2028, 'file_name': '03723.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2029, 'file_name': '00773.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2030, 'file_name': '02353.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2031, 'file_name': '00336.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2032, 'file_name': '03639.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2033, 'file_name': '02484.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2034, 'file_name': '01633.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2035, 'file_name': '02579.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2036, 'file_name': '03549.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2037, 'file_name': '00397.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2038, 'file_name': '03347.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2039, 'file_name': '02710.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2040, 'file_name': '02595.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2041, 'file_name': '03394.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2042, 'file_name': '01362.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2043, 'file_name': '00466.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2044, 'file_name': '03461.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2045, 'file_name': '02308.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2046, 'file_name': '00036.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2047, 'file_name': '00074.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2048, 'file_name': '03335.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2049, 'file_name': '01370.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2050, 'file_name': '01573.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2051, 'file_name': '03423.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2052, 'file_name': '01443.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2053, 'file_name': '00449.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2054, 'file_name': '02614.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2055, 'file_name': '00111.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2056, 'file_name': '02982.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2057, 'file_name': '00399.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2058, 'file_name': '00772.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2059, 'file_name': '00366.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2060, 'file_name': '02090.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2061, 'file_name': '00989.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2062, 'file_name': '03793.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2063, 'file_name': '02340.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2064, 'file_name': '02657.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2065, 'file_name': '03316.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2066, 'file_name': '02233.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2067, 'file_name': '01958.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2068, 'file_name': '02066.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2069, 'file_name': '02047.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2070, 'file_name': '01496.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2071, 'file_name': '00594.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2072, 'file_name': '01429.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2073, 'file_name': '01464.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2074, 'file_name': '02387.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2075, 'file_name': '03371.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2076, 'file_name': '00102.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2077, 'file_name': '00215.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2078, 'file_name': '00439.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2079, 'file_name': '03530.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2080, 'file_name': '03038.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2081, 'file_name': '01716.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2082, 'file_name': '02385.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2083, 'file_name': '03520.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2084, 'file_name': '01539.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2085, 'file_name': '01377.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2086, 'file_name': '00338.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2087, 'file_name': '03246.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2088, 'file_name': '02573.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2089, 'file_name': '03405.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2090, 'file_name': '02320.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2091, 'file_name': '02171.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2092, 'file_name': '03634.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2093, 'file_name': '01065.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2094, 'file_name': '01511.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2095, 'file_name': '03059.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2096, 'file_name': '01196.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2097, 'file_name': '00421.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2098, 'file_name': '02871.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2099, 'file_name': '00188.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2100, 'file_name': '02847.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2101, 'file_name': '01959.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2102, 'file_name': '00129.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2103, 'file_name': '02222.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2104, 'file_name': '01093.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2105, 'file_name': '00025.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2106, 'file_name': '01391.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2107, 'file_name': '02054.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2108, 'file_name': '03227.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2109, 'file_name': '01487.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2110, 'file_name': '00963.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2111, 'file_name': '01312.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2112, 'file_name': '02007.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2113, 'file_name': '00472.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2114, 'file_name': '02033.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2115, 'file_name': '01326.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2116, 'file_name': '01832.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2117, 'file_name': '01805.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2118, 'file_name': '01681.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2119, 'file_name': '00636.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2120, 'file_name': '01995.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2121, 'file_name': '02677.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2122, 'file_name': '03265.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2123, 'file_name': '01061.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2124, 'file_name': '01029.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2125, 'file_name': '01552.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2126, 'file_name': '03518.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2127, 'file_name': '03811.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2128, 'file_name': '01519.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2129, 'file_name': '02747.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2130, 'file_name': '02896.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2131, 'file_name': '02837.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2132, 'file_name': '03516.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2133, 'file_name': '03280.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2134, 'file_name': '00732.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2135, 'file_name': '03538.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2136, 'file_name': '02212.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2137, 'file_name': '01844.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2138, 'file_name': '02330.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2139, 'file_name': '02611.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2140, 'file_name': '01457.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2141, 'file_name': '02553.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2142, 'file_name': '00939.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2143, 'file_name': '03075.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2144, 'file_name': '00459.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2145, 'file_name': '01176.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2146, 'file_name': '00712.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2147, 'file_name': '02841.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2148, 'file_name': '03720.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2149, 'file_name': '03286.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2150, 'file_name': '00527.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2151, 'file_name': '00930.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2152, 'file_name': '01380.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2153, 'file_name': '00749.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2154, 'file_name': '01139.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2155, 'file_name': '03083.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2156, 'file_name': '01892.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2157, 'file_name': '00905.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2158, 'file_name': '03166.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2159, 'file_name': '02839.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2160, 'file_name': '02937.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2161, 'file_name': '00727.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2162, 'file_name': '01307.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2163, 'file_name': '00765.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2164, 'file_name': '00666.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2165, 'file_name': '01977.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2166, 'file_name': '02987.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2167, 'file_name': '02271.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2168, 'file_name': '02983.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2169, 'file_name': '00195.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2170, 'file_name': '00208.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2171, 'file_name': '00949.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2172, 'file_name': '03064.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2173, 'file_name': '00030.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2174, 'file_name': '01789.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2175, 'file_name': '03098.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2176, 'file_name': '02272.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2177, 'file_name': '00236.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2178, 'file_name': '01936.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2179, 'file_name': '03201.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2180, 'file_name': '02758.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2181, 'file_name': '00761.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2182, 'file_name': '00823.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2183, 'file_name': '00516.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2184, 'file_name': '02978.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2185, 'file_name': '03399.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2186, 'file_name': '01614.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2187, 'file_name': '00390.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2188, 'file_name': '00114.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2189, 'file_name': '01195.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2190, 'file_name': '03127.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2191, 'file_name': '01858.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2192, 'file_name': '02960.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2193, 'file_name': '00498.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2194, 'file_name': '02878.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2195, 'file_name': '02016.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2196, 'file_name': '02586.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2197, 'file_name': '00299.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2198, 'file_name': '01851.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2199, 'file_name': '00280.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2200, 'file_name': '03672.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2201, 'file_name': '03224.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2202, 'file_name': '02163.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2203, 'file_name': '03060.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2204, 'file_name': '00106.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2205, 'file_name': '02203.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2206, 'file_name': '02932.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2207, 'file_name': '03661.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2208, 'file_name': '00458.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2209, 'file_name': '02176.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2210, 'file_name': '03132.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2211, 'file_name': '02022.jpg', 'height': 3648, 'width': 5472},
#  {'id': 2212, 'file_name': '03757.jpg', 'height': 3648, 'width': 5472}]

# %%
val_ann_dic['annotations'][0]
# Out:
# {'id': 22,
#  'image_id': 2002,
#  'category_id': 6,
#  'bbox': [1729, 106, 84, 92],
#  'area': 7728,
#  'iscrowd': 0}
# {'id': 22,
#  'image_id': 2002,
#  'category_id': 6,
#  'bbox': [1729, 106, 84, 92],
#  'area': 7728,
#  'iscrowd': 0}

# %%
# count pest num for every image
numPest_per_imageId = [0] * len(images_index)

for i,ele in enumerate(images_index):
    if ele < 0:
        numPest_per_imageId[i] = ele

# %%
for i, annotation_ele in enumerate(train_ann_dic['annotations']):
    numPest_per_imageId[annotation_ele['image_id']] += 1

# %%
numImg_pestExist = 0
numPest = 0
avePest_perImg_pestExist = 0

for i,num in enumerate(numPest_per_imageId):
    if num < 0:
        continue
    if num > 0:
        numImg_pestExist += 1
        numPest += num

avePest_perImg_pestExist = numPest/numImg_pestExist
# average pest number of image that pest exists = 1.785

# %%
insect_count = []
for i,insect_ele in enumerate(train_ann_dic['categories']):
    pest_dir = os.path.join(data_root_dir,str(insect_ele['id']))
    insect_count.append(len(os.listdir(pest_dir)))
insect_count
# Out:
# [0,
#  90,
#  21,
#  20,
#  150,
#  120,
#  247,
#  14,
#  87,
#  17,
#  59,
#  18,
#  15,
#  40,
#  18,
#  12,
#  27,
#  4,
#  5,
#  4,
#  20,
#  4,
#  5,
#  3,
#  4,
#  7,
#  6,
#  1,
#  1]
# [0,
#  90,
#  21,
#  20,
#  150,
#  120,
#  247,
#  14,
#  87,
#  17,
#  59,
#  18,
#  15,
#  40,
#  18,
#  12,
#  27,
#  4,
#  5,
#  4,
#  20,
#  4,
#  5,
#  3,
#  4,
#  7,
#  6,
#  1,
#  1]

# %%
sample_mul = np.divide(max(insect_count), insect_count)
# max(insect_count)
sample_scale = np.log(sample_mul)
sample_scale = np.ceil(sample_scale + np.divide(sample_mul, 3) - 1)
sample_scale = sample_scale.astype(int)
sampleCount_aferScale = insect_count + np.multiply(insect_count, sample_scale)
sampleCount_aferScale = sampleCount_aferScale.astype(int)
numSample_before = sum(insect_count[1:])
numSample_after = sum(sampleCount_aferScale[1:])
print('sampleCount_aferScale: ', sampleCount_aferScale)
print('numSample_before: ', numSample_before)
print('numSample_after: ', numSample_after)
# Out:
# sampleCount_aferScale:  [  0 180 147 140 300 240 247 126 174 136 177 144 135 160 144 120 162 100
#  105 100 140 100 105  96 100 112 108  88  88]
# numSample_before:  1019
# numSample_after:  3974
# sampleCount_aferScale:  [  0 180 147 140 300 240 247 126 174 136 177 144 135 160 144 120 162 100
#  105 100 140 100 105  96 100 112 108  88  88]
# numSample_before:  1019
# numSample_after:  3974
# <ipython-input-47-373d66c2f804>:1: RuntimeWarning: divide by zero encountered in true_divide
#   sample_mul = np.divide(max(insect_count), insect_count)
# <ipython-input-48-373d66c2f804>:1: RuntimeWarning: divide by zero encountered in true_divide
#   sample_mul = np.divide(max(insect_count), insect_count)

# %%
test_list_111 = []
test_dic_111 = {'a':1,'b':2}
test_list_111.append(test_dic_111)
test_list_111 += [test_dic_111] * 3

# %%
cropped_pests = []

for i,insect_ele in enumerate(train_ann_dic['categories']):
    pest_dir = os.path.join(data_root_dir,str(insect_ele['id']))
    if insect_ele['id'] == 1:
        continue
    for pest_image_name in os.listdir(pest_dir):
        pest_path = os.path.join(pest_dir, pest_image_name)
        cropped_pest = {
            'category_id': insect_ele['id'],
            'file_path': pest_path
        }
        cropped_pests += [cropped_pest] * sample_scale[insect_ele['id']-1]

# %%
import random


random.seed(2022)
random.shuffle(cropped_pests)

# %%
train_ann_dic['images'][0]
# Out:
# {'id': 0, 'file_name': '00664.jpg', 'height': 3648, 'width': 5472}
# {'id': 0, 'file_name': '00664.jpg', 'height': 3648, 'width': 5472}

# %%
blank_images = []

for i,ele in enumerate(numPest_per_imageId):
    if ele == 0:
        image_path = os.path.join(img_dir,train_ann_dic['images'][images_index[i]]['file_name'])
        image_height = train_ann_dic['images'][images_index[i]]['height']
        image_width = train_ann_dic['images'][images_index[i]]['width']

        blank_image = {
            'image_id': i,
            'file_path': image_path,
            'height': image_height,
            'width': image_width
        }
        blank_images += [blank_image]

# %%
def paste_location(bigSize, smallSize):
    # [H,W],[H,W] -> left top [x,y]
    x_range = bigSize[1] - smallSize[1]
    y_range = bigSize[0] - smallSize[0]
    tlX = random.randint(0,x_range)
    tlY = random.randint(0,y_range)
    return [tlX, tlY]

# %%
x1, y1 = paste_location([1200,1200],[200,200])

# %%
# mkdir mmdetection/data/pest-coco/AUG/pasted/
from PIL import ImageFile


ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
'''# ran once
pasted_im_dir = 'mmdetection/data/pest-coco/AUG/pasted/'
pop_blank = 1

while len(cropped_pests) and len(blank_images):
    if pop_blank % 2:
        blank_image = blank_images.pop()
        blank_im = Image.open(blank_image['file_path'])
        blank_pix = np.array(blank_im)
    pop_blank += 1

    cropped_pest = cropped_pests.pop()
    cropped_im = Image.open(cropped_pest['file_path'])
    cropped_pix = np.array(cropped_im)

    big_size = [blank_image['height'],blank_image['width']]
    small_size = [cropped_pix.shape[0],cropped_pix.shape[1]]
    x1, y1 = paste_location(big_size, small_size)
    x2, y2 = x1+small_size[1], y1+small_size[0]
    blank_pix[y1:y2,x1:x2,:] = cropped_pix

    image_id = blank_image['image_id']
    max_len = len(train_ann_dic['annotations'])
    max_anno_id = train_ann_dic['annotations'][max_len-1]['id']
    anno_id = max_anno_id + 1
    category_id = cropped_pest['category_id']
    bbox = [x1, y1, x2-x1, y2-y1]
    area = bbox[2] * bbox[3]
    iscrowd = 0
    tmp_anno = {
        'id': anno_id,
        'image_id': image_id,
        'category_id': category_id,
        'bbox': bbox,
        'area': area,
        'iscrowd': iscrowd
    }
    train_ann_dic['annotations'].append(tmp_anno)
    if pop_blank % 2:
        image_name = train_ann_dic['images'][images_index[image_id]]['file_name']
        pasted_path = os.path.join(pasted_im_dir, image_name)
        pasted_im = Image.fromarray(blank_pix)
        pasted_im.save(pasted_path)
'''
# Out:
# "# ran once\npasted_im_dir = 'mmdetection/data/pest-coco/AUG/pasted/'\npop_blank = 1\n\nwhile len(cropped_pests) and len(blank_images):\n    if pop_blank % 2:\n        blank_image = blank_images.pop()\n        blank_im = Image.open(blank_image['file_path'])\n        blank_pix = np.array(blank_im)\n    pop_blank += 1\n\n    cropped_pest = cropped_pests.pop()\n    cropped_im = Image.open(cropped_pest['file_path'])\n    cropped_pix = np.array(cropped_im)\n\n    big_size = [blank_image['height'],blank_image['width']]\n    small_size = [cropped_pix.shape[0],cropped_pix.shape[1]]\n    x1, y1 = paste_location(big_size, small_size)\n    x2, y2 = x1+small_size[1], y1+small_size[0]\n    blank_pix[y1:y2,x1:x2,:] = cropped_pix\n\n    image_id = blank_image['image_id']\n    max_len = len(train_ann_dic['annotations'])\n    max_anno_id = train_ann_dic['annotations'][max_len-1]['id']\n    anno_id = max_anno_id + 1\n    category_id = cropped_pest['category_id']\n    bbox = [x1, y1, x2-x1, y2-y1]\n    area = bbox[2] * bbox[3]\n    iscrowd = 0\n    tmp_anno = {\n        'id': anno_id,\n        'image_id': image_id,\n        'category_id': category_id,\n        'bbox': bbox,\n        'area': area,\n        'iscrowd': iscrowd\n    }\n    train_ann_dic['annotations'].append(tmp_anno)\n    if pop_blank % 2:\n        image_name = train_ann_dic['images'][images_index[image_id]]['file_name']\n        pasted_path = os.path.join(pasted_im_dir, image_name)\n        pasted_im = Image.fromarray(blank_pix)\n        pasted_im.save(pasted_path)\n"
# "# ran once\npasted_im_dir = 'mmdetection/data/pest-coco/AUG/pasted/'\npop_blank = 1\n\nwhile len(cropped_pests) and len(blank_images):\n    if pop_blank % 2:\n        blank_image = blank_images.pop()\n        blank_im = Image.open(blank_image['file_path'])\n        blank_pix = np.array(blank_im)\n    pop_blank += 1\n\n    cropped_pest = cropped_pests.pop()\n    cropped_im = Image.open(cropped_pest['file_path'])\n    cropped_pix = np.array(cropped_im)\n\n    big_size = [blank_image['height'],blank_image['width']]\n    small_size = [cropped_pix.shape[0],cropped_pix.shape[1]]\n    x1, y1 = paste_location(big_size, small_size)\n    x2, y2 = x1+small_size[1], y1+small_size[0]\n    blank_pix[y1:y2,x1:x2,:] = cropped_pix\n\n    image_id = blank_image['image_id']\n    max_len = len(train_ann_dic['annotations'])\n    max_anno_id = train_ann_dic['annotations'][max_len-1]['id']\n    anno_id = max_anno_id + 1\n    category_id = cropped_pest['category_id']\n    bbox = [x1, y1, x2-x1, y2-y1]\n    area = bbox[2] * bbox[3]\n    iscrowd = 0\n    tmp_anno = {\n        'id': anno_id,\n        'image_id': image_id,\n        'category_id': category_id,\n        'bbox': bbox,\n        'area': area,\n        'iscrowd': iscrowd\n    }\n    train_ann_dic['annotations'].append(tmp_anno)\n    if pop_blank % 2:\n        image_name = train_ann_dic['images'][images_index[image_id]]['file_name']\n        pasted_path = os.path.join(pasted_im_dir, image_name)\n        pasted_im = Image.fromarray(blank_pix)\n        pasted_im.save(pasted_path)\n"

# %%
3 % 2
# Out:
# 1
# 1

# %%
import data_utils_v2

# mkdir 'mmdetection/data/pest-coco/AUG/annotations/'
train_ann_file = 'mmdetection/data/pest-coco/AUG/annotations/train_labels.json'
data_utils_v2.save_to_json(train_ann_dic, train_ann_file)
